# %% [markdown]
# <a href="https://colab.research.google.com/github/ayqazi/colab-notebooks/blob/master/chart-ixml-historical-data.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Test: Chart IXML historical data

# %%
# Install PKGs
# !pip install yfinance[nospam,repair] --upgrade --no-cache-dir

# %%
# Imports
import yfinance as yf

# %%
from google.colab import data_table
data_table.enable_dataframe_formatter()

# %% [markdown]
# # Let's do some tests

# %%
msft = yf.Ticker("MSFT")

# get all stock info
msft.info

# %%
msft.history(period="1mo")
# Out:
#                                  Open        High         Low       Close  \
# Date
# 2024-03-19 00:00:00-04:00  417.829987  421.670013  415.549988  421.410004
# 2024-03-20 00:00:00-04:00  422.000000  425.959991  420.660004  425.230011
# 2024-03-21 00:00:00-04:00  429.829987  430.820007  427.160004  429.369995
# 2024-03-22 00:00:00-04:00  429.700012  429.859985  426.070007  428.739990
# 2024-03-25 00:00:00-04:00  425.239990  427.410004  421.609985  422.859985
# 2024-03-26 00:00:00-04:00  425.609985  425.989990  421.350006  421.649994
# 2024-03-27 00:00:00-04:00  424.440002  424.450012  419.010010  421.429993
# 2024-03-28 00:00:00-04:00  420.959991  421.869995  419.119995  420.720001
# 2024-04-01 00:00:00-04:00  423.950012  427.890015  422.220001  424.570007
# 2024-04-02 00:00:00-04:00  420.109985  422.380005  417.839996  421.440002
# 2024-04-03 00:00:00-04:00  419.730011  423.260010  419.089996  420.450012
# 2024-04-04 00:00:00-04:00  424.989990  428.670013  417.570007  417.880005
# ...

# %%
msft.history(period="20y", interval="1mo")
# Out:
#                                  Open        High         Low       Close  \
# Date
# 2004-05-01 00:00:00-04:00   16.350212   16.606172   15.869507   16.375183
# 2004-06-01 00:00:00-04:00   16.312756   17.979616   16.144198   17.829786
# 2004-07-01 00:00:00-04:00   17.917176   18.660082   17.011952   17.786074
# 2004-08-01 00:00:00-04:00   17.648731   17.823532   16.762236   17.043167
# 2004-09-01 00:00:00-04:00   17.049612   17.400247   16.742806   17.312588
# ...                               ...         ...         ...         ...
# 2023-12-01 00:00:00-05:00  376.064558  377.461968  362.230126  375.345886
# 2024-01-01 00:00:00-05:00  373.169912  414.553406  365.823511  396.846130
# 2024-02-01 00:00:00-05:00  401.088267  420.043235  396.486791  412.876495
# 2024-03-01 00:00:00-05:00  411.269989  430.820007  398.390015  420.720001
# 2024-04-01 00:00:00-04:00  423.950012  429.369995  399.399994  400.524994
#
#                                Volume  Dividends  Stock Splits
# Date
# ...
